# %%
import pandas as pd
import sqlalchemy as sql
import matplotlib.pyplot as plt
db = sql.create_engine("postgresql:///dweikert")
resdf = pd.read_sql('results',db)

print(resdf)
# Out:
#     index   lifetime      latency  \
# 0       0 -22.800772  9005.143951
# 1       1 -20.792471  9104.980562
# 2       2 -21.948508  9057.672342
# 3       3 -21.387984  9263.540796
# 4       4 -21.576905  9590.666549
# 5       5 -21.451935  9288.335605
# 6       6 -21.879070  9006.159975
# 7       7 -21.088589  9027.215311
# 8       8 -22.213218  8903.644536
# 9       9 -21.324295  8851.580460
# 10     10 -22.932370  9035.685004
# 11     11 -22.568137  9198.994089
# 12     12 -21.705430  9413.125736
# 13     13 -22.180406  9382.252359
# 14     14 -22.045050  9207.362495
# 15     15 -21.057262  9123.425896
# 16     16 -22.707353  9027.147381
# 17     17 -21.687430  9219.339344
# 18     18 -22.249331  8923.723719
# 19     19 -22.205988  8952.839434
# 20     20 -20.886613  9034.124820
#
#                                              settings  \
# 0   {"nNodes": 49, "network_creator": "Grid", "dim...
# 1   {"nNodes": 49, "network_creator": "Grid", "dim...
# 2   {"nNodes": 49, "network_creator": "Grid", "dim...
# 3   {"nNodes": 49, "network_creator": "Grid", "dim...
# 4   {"nNodes": 49, "network_creator": "Grid", "dim...
# 5   {"nNodes": 49, "network_creator": "Grid", "dim...
# 6   {"nNodes": 49, "network_creator": "Grid", "dim...
# 7   {"nNodes": 49, "network_creator": "Grid", "dim...
# 8   {"nNodes": 49, "network_creator": "Grid", "dim...
# 9   {"nNodes": 49, "network_creator": "Grid", "dim...
# 10  {"nNodes": 49, "network_creator": "Grid", "dim...
# 11  {"nNodes": 49, "network_creator": "Grid", "dim...
# 12  {"nNodes": 49, "network_creator": "Grid", "dim...
# 13  {"nNodes": 49, "network_creator": "Grid", "dim...
# 14  {"nNodes": 49, "network_creator": "Grid", "dim...
# 15  {"nNodes": 49, "network_creator": "Grid", "dim...
# 16  {"nNodes": 49, "network_creator": "Grid", "dim...
# 17  {"nNodes": 49, "network_creator": "Grid", "dim...
# 18  {"nNodes": 49, "network_creator": "Grid", "dim...
# 19  {"nNodes": 49, "network_creator": "Grid", "dim...
# 20  {"nNodes": 49, "network_creator": "Grid", "dim...
#
#                                                 front
# 0   b'\x80\x04\x951\x0e\x00\x00\x00\x00\x00\x00]\x...
# 1   b'\x80\x04\x95\xbb\x12\x00\x00\x00\x00\x00\x00...
# 2   b'\x80\x04\x95\xb0\t\x00\x00\x00\x00\x00\x00]\...
# 3   b'\x80\x04\x95v\x10\x00\x00\x00\x00\x00\x00]\x...
# 4   b'\x80\x04\x95v\x10\x00\x00\x00\x00\x00\x00]\x...
# 5   b'\x80\x04\x95\x00\x15\x00\x00\x00\x00\x00\x00...
# 6   b'\x80\x04\x95v\x10\x00\x00\x00\x00\x00\x00]\x...
# 7   b'\x80\x04\x951\x0e\x00\x00\x00\x00\x00\x00]\x...
# 8   b'\x80\x04\x95/\x05\x00\x00\x00\x00\x00\x00]\x...
# 9   b'\x80\x04\x95\xec\x0b\x00\x00\x00\x00\x00\x00...
# 10  b'\x80\x04\x95\xbb\x12\x00\x00\x00\x00\x00\x00...
# 11  b'\x80\x04\x95\xbb\x12\x00\x00\x00\x00\x00\x00...
# 12  b'\x80\x04\x95\xbb\x12\x00\x00\x00\x00\x00\x00...
# 13  b'\x80\x04\x95v\x10\x00\x00\x00\x00\x00\x00]\x...
# 14  b'\x80\x04\x951\x0e\x00\x00\x00\x00\x00\x00]\x...
# 15  b'\x80\x04\x95\xec\x0b\x00\x00\x00\x00\x00\x00...
# 16  b'\x80\x04\x95\xec\x0b\x00\x00\x00\x00\x00\x00...
# 17  b'\x80\x04\x95k\x07\x00\x00\x00\x00\x00\x00]\x...
# 18  b'\x80\x04\x95k\x07\x00\x00\x00\x00\x00\x00]\x...
# 19  b'\x80\x04\x95\xa7\t\x00\x00\x00\x00\x00\x00]\...
# 20  b'\x80\x04\x95v\x10\x00\x00\x00\x00\x00\x00]\x...

# %%
# %matplotlib inline
#printing fronts
import pickle as pck
from deap import creator, base
from individual import ListWithAttributes

import numpy as np
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    creator.create("FitnessMin", base.Fitness, weights=(-1.0,-1.0))
    creator.create("Individual", ListWithAttributes, fitness=creator.FitnessMin)

#resdf.set_index('index', inplace=True)
fronts = resdf['front']
fronts = [pck.loads(x) for x in fronts]
for experiment_run in fronts:
    fig, axes = plt.subplots(1,len(experiment_run), figsize=(10,4))
    i=0
    for front in experiment_run: 
        front = [x for x in front if x.fitness.values[1]<9999]
        obj = np.array([ind.fitness.values for ind in front])
        axes[i].scatter(obj[:,0], obj[:,1]/1000, c='b')
        i+=1
    plt.show()
